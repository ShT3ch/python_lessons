# %%
import cv2
import numpy as np
from matplotlib import pyplot
# %matplotlib inline

# %%
b = cv2.imread('./../predictions.png')

# %%
pyplot.imshow(b)

# %%
pyplot.imshow(cv2.circle(b, (0,0), 50, (0,0,200), -1))
